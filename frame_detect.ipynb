# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
i = cv2.imread('frames0102/frame0001.jpg')
plt.imshow(i)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
import cv2 as cv
im = cv.imread('frames0102/frame0001.jpg')
imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
edges = cv.Canny(imgray, 50, 200)
contours, hierarchy = cv.findContours(
    edges, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
cv.drawContours(im, contours, -1, (0, 255, 0), 3)
# cv.imshow('test', im)
cv.waitKey(0)
# Out:
# -1

# %%
contours.__dir__()
cont = np.array(contours)
# Out:
# C:\Users\trakw\AppData\Local\Temp\ipykernel_11632\734771999.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   cont = np.array(contours)

# %%
mintemp = []
for i, x in enumerate(contours):
  # print(i)
  xnp = np.array(x)
  mintemp.append(np.amin(xnp, axis=0)[0])
mintemp
# Out:
# [array([651, 987], dtype=int32),
#  array([802, 331], dtype=int32),
#  array([778, 317], dtype=int32),
#  array([689, 271], dtype=int32),
#  array([685, 252], dtype=int32),
#  array([847, 239], dtype=int32),
#  array([653, 239], dtype=int32),
#  array([834, 175], dtype=int32),
#  array([643, 130], dtype=int32)]

# %%
2000-contours[0][0]
# Out:
# array([[1327, 1013]], dtype=int32)

# %%
c0 = np.array(contours[0])
c0 = np.resize(c0, (c0.shape[0],2))
print(c0.shape)
minindex = np.argmax(c0, axis=0)
minindex[1]
# Out:
# (362, 2)
# array([139,  66], dtype=int64)

# %%
c0 = np.resize(c0, (c0.shape[0],2))

# %%
c0
# Out:
# array([[ 673,  987],
#        [ 672,  988],
#        [ 671,  988],
#        [ 670,  989],
#        [ 670,  990],
#        [ 668,  992],
#        [ 668,  993],
#        [ 667,  994],
#        [ 667,  996],
#        [ 666,  997],
#        [ 666,  998],
#        [ 665,  999],
#        [ 665, 1001],
#        [ 664, 1002],
#        [ 664, 1004],
#        [ 663, 1005],
#        [ 663, 1008],
#        [ 662, 1009],
#        [ 662, 1012],
#        [ 661, 1013],
#        [ 661, 1017],
#        [ 660, 1018],
#        [ 660, 1021],
#        [ 659, 1022],
#        [ 659, 1028],
#        [ 658, 1029],
#        [ 658, 1037],
#        [ 657, 1038],
#        [ 657, 1044],
#        [ 656, 1045],
#        [ 656, 1054],
#        [ 655, 1055],
#        [ 655, 1064],
#        [ 654, 1065],
#        [ 654, 1079],
#        [ 653, 1080],
#        [ 653, 1105],
#        [ 652, 1106],
#        [ 652, 1154],
#        [ 651, 1155],
#        [ 651, 1167],
#        [ 652, 1168],
#        [ 652, 1173],
# ...
